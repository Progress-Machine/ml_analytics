# %% [markdown]
# ## юзаем в проде

# %%
# %load_ext autoreload
# %autoreload 2

from full_pipeline import get_predict_by_link, get_predict_for_new_product
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
json_data_product, revenue, analys = get_predict_by_link("https://www.wildberries.ru/catalog/47836707/detail.aspx")
# Out:
# E:\DIR_python_projects\generation_hack\ml_analytics\get_analytics.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nearest_dataframe["revenue"] = nearest_dataframe.order_count * nearest_dataframe.price

# %%
revenue
# Out:
# 6987717.567148073

# %%
json_data_product
# Out:
# {'name': 'Постельное белье 2 спальное комплект поплин',
#  'url': 'https://www.wildberries.ru/catalog/47836707/detail.aspx',
#  'price': 2220.0,
#  'old_price': '5550',
#  'order_count': 5800.0,
#  'celler_sold': 1462786,
#  'celler_rating': 4.5,
#  'name_comp': 'ПРОТЕКС',
#  'celler_mean_delivery_time': '95.3%',
#  'celler_percent_bad_products': '0.1%',
#  'celler_working_time': '5 лет и 10 мес',
#  'celler_link': 'https://www.wildberries.ru/seller/17363',
#  'img_link': 'https://basket-04.wb.ru/vol478/part47836/47836707/images/big/1.webp',
#  'description': 'Постельдное белье топ!!!!',
#  'text_params': ['Дополнительная информация Вид ткани постельного белья полотняное (поплин) Плотность ткани 115 г/кв.м Размер постельного белья 2 спальное с евро простыней; 2х спальное; 2 спальное поплин Размер пододеяльника 175х215 см Особенности простыни классическая; без резинки; под заправку',
# ...

# %% [markdown]
# ### улучшаем характеристики товара

# %%
json_data_product["description"] = "Постельдное белье топ!!!!"

# %%
json_data_product_2, revenue_2, analys_2 = get_predict_for_new_product(json_data_product)
# Out:
# E:\DIR_python_projects\generation_hack\ml_analytics\get_analytics.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nearest_dataframe["revenue"] = nearest_dataframe.order_count * nearest_dataframe.price

# %%
json_data_product_2
# Out:
# {'name': 'Постельное белье 2 спальное комплект поплин',
#  'url': 'https://www.wildberries.ru/catalog/47836707/detail.aspx',
#  'price': 2220.0,
#  'old_price': '5550',
#  'order_count': 5800.0,
#  'celler_sold': 1462786,
#  'celler_rating': 4.5,
#  'name_comp': 'ПРОТЕКС',
#  'celler_mean_delivery_time': '95.3%',
#  'celler_percent_bad_products': '0.1%',
#  'celler_working_time': '5 лет и 10 мес',
#  'celler_link': 'https://www.wildberries.ru/seller/17363',
#  'img_link': 'https://basket-04.wb.ru/vol478/part47836/47836707/images/big/1.webp',
#  'description': 'Постельдное белье топ!!!!',
#  'text_params': ['Дополнительная информация Вид ткани постельного белья полотняное (поплин) Плотность ткани 115 г/кв.м Размер постельного белья 2 спальное с евро простыней; 2х спальное; 2 спальное поплин Размер пододеяльника 175х215 см Особенности простыни классическая; без резинки; под заправку',
# ...

# %%
revenue_2
# Out:
# 7359155.807467569

# %% [markdown]
# ## еще облако слов популярных описаний

# %%
from PIL import Image
world_cloud = Image.open("tmp_files/world_cloud.png")
world_cloud
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1080>
